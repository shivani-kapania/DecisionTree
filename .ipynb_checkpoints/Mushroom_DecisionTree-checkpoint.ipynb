# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline

# %%
ds = pd.read_csv('./mushrooms.csv')
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# target                      8124 non-null object
# cap_shape                   8124 non-null object
# cap_surface                 8124 non-null object
# cap_color                   8124 non-null object
# bruises                     8124 non-null object
# odor                        8124 non-null object
# gill_attachment             8124 non-null object
# gill_spacing                8124 non-null object
# gill_size                   8124 non-null object
# gill_color                  8124 non-null object
# stalk_shape                 8124 non-null object
# stalk_root                  8124 non-null object
# stalk_surface_above_ring    8124 non-null object
# stalk_surface_below_ring    8124 non-null object
# stalk_color_above_ring      8124 non-null object
# stalk_color_below_ring      8124 non-null object
# veil_type                   8124 non-null object
# ...

# %%
def convert_target_to_num(s):
    if s=='p':
        return 0
    elif s=='e':
        return 1
    else:
        return s
    

ds.target = ds.target.map(convert_target_to_num)
ds.head()
# Out:
#    target cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0       0         x           s         n       t    p               f
# 1       1         x           s         y       t    a               f
# 2       1         b           s         w       t    l               f
# 3       0         x           y         w       t    p               f
# 4       1         x           s         g       f    n               f
#
#   gill_spacing gill_size gill_color   ...   stalk_surface_below_ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# ...

# %%
def convert_cap_shape_to_num(s):
    if s=='b':
        return 0
    if s=='c':
        return 1
    elif s=='x':
        return 2
    elif s=='f':
        return 3
    elif s=='k':
        return 4
    elif s=='s':
        return 5
    else:
        return s

    
   
ds.cap_shape = ds.cap_shape.map(convert_cap_shape_to_num)

# %%
def convert_cap_surface_to_num(s):
    if s=='f':
        return 0
    elif s=='g':
        return 1
    elif s=='y':
        return 2
    elif s=='s':
        return 3
    else:
        return s
    

ds.cap_surface = ds.cap_surface.map(convert_cap_surface_to_num)

# %%
def convert_cap_color_to_num(s):
    if s=='n':
        return 0
    elif s=='b':
        return 1
    elif s=='c':
        return 2
    elif s=='g':
        return 3
    elif s=='r':
        return 4
    elif s=='p':
        return 5
    elif s=='u':
        return 6
    elif s=='e':
        return 7
    elif s=='w':
        return 8
    elif s=='y':
        return 9
    else:
        return s
    
ds.cap_color = ds.cap_color.map(convert_cap_color_to_num)
#ds.head()

# %%
def convert_bruises_to_num(s):
    if s=='t':
        return 0
    elif s=='f':
        return 1
    else:
        return s

ds.bruises = ds.bruises.map(convert_bruises_to_num)
ds.head()
# Out:
#    target  cap_shape  cap_surface  cap_color  bruises odor gill_attachment  \
# 0       0          2            3          0        0    p               f
# 1       1          2            3          9        0    a               f
# 2       1          0            3          8        0    l               f
# 3       0          2            2          8        0    p               f
# 4       1          2            3          3        1    n               f
#
#   gill_spacing gill_size gill_color   ...   stalk_surface_below_ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# ...

# %%
def convert_odor_to_num(s):
    if s=='a':
        return 0
    elif s=='l':
        return 1
    elif s=='c':
        return 2
    elif s=='y':
        return 3
    elif s=='f':
        return 4
    elif s=='m':
        return 5
    elif s=='n':
        return 6
    elif s=='p':
        return 7
    elif s=='s':
        return 8
    else:
        return s
    
ds.odor = ds.odor.map(convert_odor_to_num)
#ds.head()

# %%
def convert_gill_attachment_to_num(s):
    if s=='a':
        return 0
    elif s=='d':
        return 1
    elif s=='f':
        return 2
    elif s=='n':
        return 3
    else:
        return s
    
ds.gill_attachment = ds.gill_attachment.map(convert_gill_attachment_to_num)
ds.head()
# Out:
#    target  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0       0          2            3          0        0     7                2
# 1       1          2            3          9        0     0                2
# 2       1          0            3          8        0     1                2
# 3       0          2            2          8        0     7                2
# 4       1          2            3          3        1     6                2
#
#   gill_spacing gill_size gill_color   ...   stalk_surface_below_ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# ...

# %%
def convert_gill_spacing_to_num(s):
    if s=='c':
        return 0
    elif s=='w':
        return 1
    elif s=='d':
        return 2
    else:
        return s
    
ds.gill_spacing = ds.gill_spacing.map(convert_gill_spacing_to_num)

# %%
def convert_gill_size_to_num(s):
    if s=='b':
        return 0
    elif s=='n':
        return 1
    else:
        return s
    
ds.gill_size = ds.gill_size.map(convert_gill_size_to_num)

# %%
def convert_gill_color_to_num(s):
    if s=='k':
        return 0
    elif s=='n':
        return 1
    elif s=='b':
        return 2
    elif s=='h':
        return 3
    elif s=='g':
        return 4
    elif s=='r':
        return 5
    elif s=='o':
        return 6
    elif s=='p':
        return 7
    elif s=='u':
        return 8
    elif s=='e':
        return 9
    elif s=='w':
        return 10
    elif s=='y':
        return 11
    else:
        return s
    
ds.gill_color = ds.gill_color.map(convert_gill_color_to_num)

# %%
def convert_stalk_shape_to_num(s):
    if s=='e':
        return 0
    elif s=='t':
        return 1
    else:
        return s
    
ds.stalk_shape = ds.stalk_shape.map(convert_stalk_shape_to_num)

# %%
def convert_stalk_root_to_num(s):
    if s=='b':
        return 0
    elif s=='c':
        return 1
    elif s=='u':
        return 2
    elif s=='e':
        return 3
    elif s=='z':
        return 4
    elif s=='r':
        return 5
    elif s=='?':
        return 6
    else:
        return s
    
ds.stalk_root = ds.stalk_root.map(convert_stalk_root_to_num)

# %%
def convert_stalk_surface_to_num(s):
    if s=='f':
        return 0
    elif s=='y':
        return 1
    elif s=='k':
        return 2
    elif s=='s':
        return 3
    else:
        return s
    
ds.stalk_surface_below_ring = ds.stalk_surface_below_ring.map(convert_stalk_surface_to_num)
ds.stalk_surface_above_ring = ds.stalk_surface_above_ring.map(convert_stalk_surface_to_num)

# %%
def convert_stalk_color_to_num(s):
    if s=='n':
        return 0
    elif s=='b':
        return 1
    elif s=='c':
        return 2
    elif s=='g':
        return 3
    elif s=='o':
        return 4
    elif s=='p':
        return 5
    elif s=='e':
        return 6
    elif s=='w':
        return 7
    elif s=='y':
        return 8
    else:
        return s
    
ds.stalk_color_above_ring = ds.stalk_color_above_ring.map(convert_stalk_color_to_num)
ds.stalk_color_below_ring = ds.stalk_color_below_ring.map(convert_stalk_color_to_num)

# %%
def convert_veil_type_to_num(s):
    if s=='p':
        return 0
    elif s=='u':
        return 1
    else:
        return s
    
ds.veil_type = ds.veil_type.map(convert_veil_type_to_num)

# %%
def convert_veil_color_to_num(s):
    if s=='n':
        return 0
    elif s=='o':
        return 1
    elif s=='w':
        return 2
    elif s=='y':
        return 3
    else:
        return s
    
ds.veil_color = ds.veil_color.map(convert_veil_color_to_num)

# %%
def convert_ring_number_to_num(s):
    if s=='n':
        return 0
    elif s=='o':
        return 1
    elif s=='t':
        return 2
    else:
        return s
    
ds.ring_number = ds.ring_number.map(convert_ring_number_to_num)

# %%
def convert_ring_type_to_num(s):
    if s=='c':
        return 0
    elif s=='e':
        return 1
    elif s=='f':
        return 2
    elif s=='l':
        return 3
    elif s=='n':
        return 4
    elif s=='p':
        return 5
    elif s=='s':
        return 6
    elif s=='z':
        return 7
    else:
        return s
    
ds.ring_type = ds.ring_type.map(convert_ring_type_to_num)

# %%
def convert_spore_print_color_to_num(s):
    if s=='k':
        return 0
    elif s=='n':
        return 1
    elif s=='b':
        return 2
    elif s=='h':
        return 3
    elif s=='r':
        return 4
    elif s=='o':
        return 5
    elif s=='u':
        return 6
    elif s=='w':
        return 7
    elif s=='y':
        return 8
    else:
        return s
    
ds.spore_print_color = ds.spore_print_color.map(convert_spore_print_color_to_num)

# %%
def convert_population_to_num(s):
    if s=='a':
        return 0
    elif s=='c':
        return 1
    elif s=='n':
        return 2
    elif s=='s':
        return 3
    elif s=='v':
        return 4
    elif s=='y':
        return 5
    else:
        return s
    
ds.population = ds.population.map(convert_population_to_num)

# %%
def convert_habitat_to_num(s):
    if s=='g':
        return 0
    elif s=='l':
        return 1
    elif s=='m':
        return 2
    elif s=='p':
        return 3
    elif s=='u':
        return 4
    elif s=='w':
        return 5
    elif s=='d':
        return 6
    else:
        return s
    
ds.habitat = ds.habitat.map(convert_habitat_to_num)

# %%
ds.head()
# Out:
#    target  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0       0          2            3          0        0     7                2
# 1       1          2            3          9        0     0                2
# 2       1          0            3          8        0     1                2
# 3       0          2            2          8        0     7                2
# 4       1          2            3          3        1     6                2
#
#    gill_spacing  gill_size  gill_color   ...     stalk_surface_below_ring  \
# 0             0          1           0   ...                            3
# 1             0          0           0   ...                            3
# 2             0          0           1   ...                            3
# 3             0          1           1   ...                            3
# 4             1          0           0   ...                            3
#
# ...

# %%
data = ds.dropna()
data.head()
data = data.reset_index(drop=True)

# %%
data.shape
# Out:
# (8124, 23)

# %%
plt.figure()
sns.heatmap(data.corr())

# %%
data.shape
# Out:
# (8124, 23)

# %%
#split the data 
split = int(0.8*data.shape[0])

training_data = data[:split]
testing_data = data[split:]

print training_data.shape, testing_data.shape
# Out:
# (6499, 23) (1625, 23)

# %%
#split the columns
input_cols = list(data.columns.values)
input_cols.pop(0)
print input_cols

out_cols = ['target']
print out_cols
# Out:
# ['cap_shape', 'cap_surface', 'cap_color', 'bruises', 'odor', 'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color', 'stalk_shape', 'stalk_root', 'stalk_surface_above_ring', 'stalk_surface_below_ring', 'stalk_color_above_ring', 'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number', 'ring_type', 'spore_print_color', 'population', 'habitat']
# ['target']

# %%
training_data_x = training_data[input_cols]
training_data_y = training_data[out_cols]
print training_data_x.shape, training_data_y.shape

testing_data_x = testing_data[input_cols]
testing_data_y = testing_data[out_cols]
print testing_data_x.shape, testing_data_y.shape
# Out:
# (6499, 22) (6499, 1)
# (1625, 22) (1625, 1)

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(training_data_x, training_data_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
clf.predict(testing_data_x)
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
clf.score(testing_data_x, testing_data_y)
# Out:
# 1.0
